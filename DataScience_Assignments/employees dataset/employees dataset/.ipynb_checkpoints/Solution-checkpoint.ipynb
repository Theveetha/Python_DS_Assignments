# %%
# Import the Relevant Packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the dataset.
# Check the shape
# Show the top records
df = pd.read_csv("employees.csv")
print( df.shape )
df.head()
# Out:
# (1000, 8)
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
# Find the Average Salary and Average Bonus.
print( df['Salary'].mean() )
print( df['Bonus %'].mean() )
# Out:
# 90662.181
# 10.207555

# %%
# Check for the Datatypes and Structre
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
# Convert the Start Date as datetime64
# HINT : .astype('datetime64')

df['Salary'].astype("str") # temporary
df['Start Date'] = df['Start Date'].astype("datetime64") # permanent

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
# Find out how many are there in Senior Management

res = df['Senior Management'].value_counts()
print( res )
print( res[True] )
print( res[1] )
# Out:
# True     468
# False    465
# Name: Senior Management, dtype: int64
# 468
# 468

# %%
res = df[ df['Senior Management'] == True ]['Senior Management']
print( res.sum() )
print( res.count() )
# Out:
# 468
# 468

# %%
# Display the chart for the "Senior Management" highlighting the COUNT
# Out:
# True     468
# False    465
# Name: Senior Management, dtype: int64
# C:\Users\Nitish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['Senior Management'], color = 'g')
plt.show()
# Out:
# e:\Installations\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
year_count = df['Start Date']
year_count
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[ns]

# %%
df['Start Date'].apply( lambda x  : str(x).split("-")[0]  )

# x = 1993-08-06
# x = "1993-08-06"
# Out:
# 0      1993
# 1      1996
# 2      1993
# 3      2005
# 4      1998
#        ...
# 995    2014
# 996    1984
# 997    2013
# 998    2013
# 999    2012
# Name: Start Date, Length: 1000, dtype: object

# %%
df['Year'] = df['Start Date'].dt.year
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team  Year
# 0              True        Marketing  1993
# 1              True              NaN  1996
# 2             False          Finance  1993
# 3              True          Finance  2005
# 4              True  Client Services  1998

# %%
df['Year'].value_counts().head(1)
# Out:
# 1995    44
# Name: Year, dtype: int64

# %%
df['Year'].value_counts().tail(3)
# Out:
# 1985    18
# 1987    16
# 2016    15
# Name: Year, dtype: int64

# %%
year_count = df['Year'].value_counts()
print( year_count.index.values )
print( year_count.values )
# Out:
# [1995 2009 1999 2002 2007 1996 1984 2005 2004 1980 2011 1997 2013 2014
#  2010 1986 1982 2012 1992 1991 2003 2000 2006 1988 2008 2001 1994 1990
#  2015 1983 1981 1989 1998 1993 1985 1987 2016]
# [44 42 37 34 33 32 32 31 31 30 30 29 29 28 28 28 28 28 28 27 26 26 26 25
#  25 25 24 22 22 22 21 20 19 19 18 16 15]

# %%
# Two - Year in which company had maximum HIRE and Min Hire

sns.lineplot( x = year_count.index.values , y = year_count.values  )
plt.show()

# %%
# Find the Team that is having the highest number of records.
# Visualizae the results as Well

# %%
team_count = df['Team'].value_counts()
print( team_count.index.values )
print( team_count.values )
# Out:
# ['Client Services' 'Finance' 'Business Development' 'Marketing' 'Product'
#  'Sales' 'Engineering' 'Human Resources' 'Distribution' 'Legal']
# [106 102 101  98  95  94  92  91  90  88]

# %%
plt.pie( x = team_count.values, labels=team_count.index.values, startangle=0, counterclock=False )  
plt.show()

# %%
plt.figure( figsize=(20, 6) )
plt.bar( x = team_count.index.values, height=team_count.values )
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure( figsize=(20, 6) )
sns.barplot( x = team_count.index.values, y=team_count.values, palette="Greens" )
plt.xticks(rotation = 45)
plt.show()

# %%
# # Visualizae the Salary Analysis of the dataset

# %%
sns.histplot( df['Salary'], color="magenta", bins = 25 )
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
# Find the Gender that is having the highest number of records.
# Visualizae the results as Well
# Out:
# C:\Users\Nitish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Find the columns having maximum NA values

# df.sort_values(by = 'Salary', ascending = False)
print( type(df.isna().sum()) )
print( df.isna().sum() )

df.isna().sum().sort_values(ascending=False).head(1)
# Out:
# <class 'pandas.core.series.Series'>
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# Year                   0
# dtype: int64
# Gender    145
# dtype: int64

# %%
teams = df.groupby("Team").agg(totalRecords = ("Team", np.size) , 
                                   AvgBonus = ("Bonus %" , np.mean), 
                                   avgSalary = ('Salary',np.mean))
teams.head()
# Out:
#                       totalRecords   AvgBonus     avgSalary
# Team
# Business Development           101  10.572376  91866.316832
# Client Services                106  10.495104  88224.424528
# Distribution                    90   9.615644  88500.466667
# Engineering                     92  10.462989  94269.195652
# Finance                        102  10.186873  92219.480392

# %%
## ** LOOPS here....
### Think --


# plt.subplot(1 , 3 , <<POSITION>>)
# teams = teams.sort_values(by = f<<ColumnName>>, ascending = False)  # Sorted the group on the basis of column
# plt.pie( x = teams[f<<ColumnName>>].values , labels=teams.index.values, 
#         startangle=0, shadow= True, counterclock=False, autopct = "%.1f%%" ) #x is Numebrs, labels is Index
# plt.title(f"Teams vs <<ColumnName>>", fontsize = 12)

# %%
plt.figure( figsize=(20, 8) )
plt.suptitle("Teams Analysis", fontsize = 18)

plt.subplot(1 , 3 , 1)
teams = teams.sort_values(by = "totalRecords", ascending = False)  # Sorted the group on the basis of column
plt.pie( x = teams['totalRecords'].values , labels=teams.index.values, 
        startangle=0, shadow= True, counterclock=False, autopct = "%.1f%%" ) #x is Numebrs, labels is Index
plt.title("Teams vs Records", fontsize = 12)


plt.subplot(1 , 3 , 2)
teams = teams.sort_values(by = "AvgBonus", ascending = False)  # Sorted the group on the basis of column
plt.pie( x = teams['AvgBonus'].values , labels=teams.index.values, 
        startangle=0, shadow= True, counterclock=False, autopct = "%.1f%%" ) #x is Numebrs, labels is Index
plt.title("Teams vs AvgBonus", fontsize = 12)


plt.subplot(1 , 3 , 3)
teams = teams.sort_values(by = "avgSalary", ascending = False)  # Sorted the group on the basis of column
plt.pie( x = teams['avgSalary'].values , labels=teams.index.values, 
        startangle=0, shadow= True, counterclock=False, autopct = "%.1f%%" ) #x is Numebrs, labels is Index
plt.title("Teams vs avgSalary", fontsize = 12)


plt.show()

# %%
# Visualizae the results of the Team with respect to Average Salary and Bonus. Make Pie or Bar Chart
# Out:
#                       totalRecords     AvgSalary   AvgBonus
# Team
# Business Development           101  91866.316832  10.572376
# Client Services                106  88224.424528  10.495104
# Distribution                    90  88500.466667   9.615644
# Engineering                     92  94269.195652  10.462989
# Finance                        102  92219.480392  10.186873
# Human Resources                 91  90944.527473   9.993879
# Legal                           88  89303.613636  10.322830
# Marketing                       98  90435.591837  10.353449
# Product                         95  88665.505263   9.791484
# Sales                           94  92173.436170  10.116915

# %%
# Visualizae the results of the Team with respect to Average Salary and Bonus. Make Pie or Bar Chart
# Out:
#                       totalRecords     AvgSalary   AvgBonus
# Team
# Business Development           101  91866.316832  10.572376
# Client Services                106  88224.424528  10.495104
# Distribution                    90  88500.466667   9.615644
# Engineering                     92  94269.195652  10.462989
# Finance                        102  92219.480392  10.186873
# Human Resources                 91  90944.527473   9.993879
# Legal                           88  89303.613636  10.322830
# Marketing                       98  90435.591837  10.353449
# Product                         95  88665.505263   9.791484
# Sales                           94  92173.436170  10.116915

# %%
# Find the Business Development employee that are having salary more than 1 lac

df[ ( df['Team'] == "Business Development")  &  ( df['Salary'] >= 100000 ) ].head()
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 9     Frances  Female 2002-08-08         6:51 AM  139852    7.524
# 33       Jean  Female 1993-12-18         9:07 AM  119082   16.180
# 36     Rachel  Female 2009-02-16         8:47 PM  142032   12.599
# 61     Denise  Female 2001-11-06        12:03 PM  106862    3.699
# 66      Nancy  Female 2012-12-15        11:57 PM  125250    2.672
#
#    Senior Management                  Team  Year
# 9               True  Business Development  2002
# 33             False  Business Development  1993
# 36             False  Business Development  2009
# 61             False  Business Development  2001
# 66              True  Business Development  2012

# %%
# Find the Finance employee that are having salary less than 50K

df[ ( df['Team'] == "Finance")  &  ( df['Salary'] <= 50000 ) ].shape
# Out:
# (13, 9)

# %%
df[ df['Year'] == 1995 ].head()
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN 1995-04-22         7:18 PM   64714    4.934
# 21     Matthew   Male 1995-09-05         2:12 AM  100612   13.645
# 74      Thomas   Male 1995-06-04         2:24 PM   62096   17.029
# 80      Gerald    NaN 1995-03-17        12:50 AM  137126   15.602
# 117     Steven   Male 1995-03-01         3:03 PM  109095    9.494
#
#     Senior Management       Team  Year
# 20               True      Legal  1995
# 21              False  Marketing  1995
# 74              False  Marketing  1995
# 80               True      Sales  1995
# 117             False    Finance  1995

# %%
max_salary = df[ df['Year'] == 1995 ]['Salary'].max()
max_salary
# Out:
# 148339

# %%
df[  ( df['Year'] == 1995 ) &  (  df['Salary'] == max_salary) ]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 765      Alice    NaN 1995-04-23         6:35 AM  148339   11.479
#
#     Senior Management     Team  Year
# 765              True  Finance  1995

# %%
# Find the employees who joined the organization in 1995, with salary being the highest in that YEAR
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 765      Alice    NaN 1995-04-23         6:35 AM  148339   11.479
#
#     Senior Management     Team  \
# 765              True  Finance
#
#                                      Last Login Time 2
# 765  <pandas.core.strings.StringMethods object at 0...

# %%
# Find the employees who joined the organization in 2009, with salary being the highest in that YEAR
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 740    Russell    NaN 2009-05-09        11:59 AM  149456    3.533
#
#     Senior Management       Team  \
# 740             False  Marketing
#
#                                      Last Login Time 2
# 740  <pandas.core.strings.StringMethods object at 0...

# %%
## Year Analysis
## Year Analysis. Create a new column for Year from Start Date column
# Out:
#       totalRecords     AvgSalary  MaxSalary  MinSalary   AvgBonus
# Year
# 1980            30  80666.333333     145357      35095  10.164900
# 1981            21  90886.285714     145988      37748  10.679238
# 1982            28  94920.500000     147183      35061   9.239571
# 1983            22  87492.363636     145988      36759  10.970864
# 1984            32  86175.406250     134120      36837  11.700844

# %%
# df.rename(columns = {"Bonus %" : "Bonus"})
# df.columns = [ col.strip() for col in df.columns ]
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team', 'Year'],
#       dtype='object')

# %%
year_group = df.groupby("Year").agg(totalRecords = ("Year", np.size) , 
                                   AvgBonus = ("Bonus %" , np.mean))
year_group.head()
# Out:
#       totalRecords   AvgBonus
# Year
# 1980            30  10.164900
# 1981            21  10.679238
# 1982            28   9.239571
# 1983            22  10.970864
# 1984            32  11.700844

# %%
year_group.sort_values(by = "AvgBonus", ascending = False).head()
# Out:
#       totalRecords   AvgBonus
# Year
# 1985            18  12.524278
# 1989            20  12.490250
# 1984            32  11.700844
# 2014            28  11.384429
# 1997            29  11.281069

# %%
year_group = df.groupby("Year").agg(totalRecords = ("Year", np.size) , 
                                   AvgBonus = ("Bonus %" , np.mean), 
                                   max_salary = ('Salary',np.max))
year_group.head()
# Out:
#       totalRecords   AvgBonus  max_salary
# Year
# 1980            30  10.164900      145357
# 1981            21  10.679238      145988
# 1982            28   9.239571      147183
# 1983            22  10.970864      145988
# 1984            32  11.700844      134120

# %%
df[df['Year'] == 1980]['Salary'].max()
# Out:
# 145357

# %%
## Find the top 5 Yearss in accordance with the Highest Salaries Joining In

year_group = df.groupby("Year").agg(totalRecords = ("Year", np.size) , 
                                   AvgBonus = ("Bonus %" , np.mean), 
                                   max_salary = ('Salary',np.max))
year_group = year_group.sort_values(by = "max_salary", ascending = False)
year_group.head()
# Out:
#       totalRecords   AvgBonus  max_salary
# Year
# 1996            32  10.192156      149908
# 2015            22  10.512500      149903
# 2006            26   9.125654      149684
# 2005            31  10.677710      149654
# 2000            26   9.440615      149563

# %%
## Find the top 5 Yearss in accordance with the Highest Acverage Salaries Joining In

# %%
# pandas
# numpy 2
# math 1
# os 6
